# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import os
from sqlalchemy import create_engine

# %% [markdown]
# Creating Connection and Loading Data to SQL Database

# %%
engine = create_engine(
    "mssql+pyodbc://localhost/vendor_project?"
    "driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes"
)

# %%
for file in os.listdir('data'):
    if ".csv" in file:
        df = pd.read_csv('data/'+file)
        print(df.shape)
        ingest_db(df,file[:-4],engine)
# Out:
# (206529, 9)
# (224489, 9)
# (2372474, 16)
# (12261, 9)
# (12825363, 14)
# (5543, 10)

# %%
def ingest_db(df,table_name,engine):
    df.to_sql(table_name,con=engine,if_exists='replace',index=False)

# %% [markdown]
# Checking Table Present In Database

# %%
tables = pd.read_sql_query("select table_name from information_schema.tables where table_type = 'Base Table'",engine)
tables
# Out:
#         table_name
# 0  begin_inventory
# 1    end_inventory
# 2        purchases
# 3  purchase_prices
# 4            sales
# 5   vendor_invoice

# %% [markdown]
# Checking All Table Data

# %%
for table in tables['table_name']:
    print('_'*50,f'{table}','_'*50)
    print('Count of Records : ',pd.read_sql(f"Select count(*) as count from {table}",engine)['count'].values[0])
    display(pd.read_sql(f"select top 5 * from {table}",engine))
# Out:
# __________________________________________________ begin_inventory __________________________________________________
# Count of Records :  206529
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
# 2  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
# 3  1_HARDERSFIELD_63      1  HARDERSFIELD     63   Herradura Reposado Tequila
# 4  1_HARDERSFIELD_72      1  HARDERSFIELD     72         No. 3 London Dry Gin
#
#     Size  onHand  Price   startDate
# 0  750mL       8  12.99  2024-01-01
# 1  750mL       7  10.99  2024-01-01
# 2  750mL       6  36.99  2024-01-01
# 3  750mL       3  38.99  2024-01-01
# 4  750mL       6  34.99  2024-01-01
# __________________________________________________ end_inventory __________________________________________________
# ...

# %% [markdown]
# Data Extraction from SQL Server and Exploration

# %%
purchases = pd.read_sql("select * from purchases",engine)
purchases.head()
# Out:
#            InventoryId  Store  Brand                   Description   Size  \
# 0    69_MOUNTMEND_8412     69   8412     Tequila Ocho Plata Fresno  750mL
# 1     30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 2    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 3  1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 4    76_DONCASTER_2034     76   2034     Glendalough Double Barrel  750mL
#
#    VendorNumber                   VendorName  PONumber      PODate  \
# 0           105  ALTAMAR BRANDS LLC               8124  2023-12-21
# 1          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 2          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 3          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 4           388  ATLANTIC IMPORTING COMPANY       8169  2023-12-24
#
#   ReceivingDate InvoiceDate     PayDate  PurchasePrice  Quantity  Dollars  \
# ...

# %% [markdown]
# The purchases table contain data actual purchase data , including purchase date, Brand , Price , Quantity and Total amount(in Dollars).

# %%
purchase_prices = pd.read_sql("select * from purchase_prices",engine)
purchase_prices
# Out:
#        Brand                   Description  Price   Size Volume  \
# 0      19150  Esclans Whispering Angel Ros  21.99  750mL    750
# 1      19251               Bonterra Pnt Nr  11.99  750mL    750
# 2      19394  Dom du Gr Montmirall Gigonda  29.99  750mL    750
# 3      19436   Jean Luc Colombo Ruchets 10  69.99  750mL    750
# 4      19495  Pierre Luc Bouchard Muscadet  11.99  750mL    750
# ...      ...                           ...    ...    ...    ...
# 12256  18859            Mercat Brut Nature  14.99  750mL    750
# 12257  18974  Pine Ridge Napa Vlly Cab Svg  49.99  750mL    750
# 12258  19060      Chateau Dalem 10 Fronsac  34.99  750mL    750
# 12259  19139  Gerard Bertrand Orgnic Chard   9.99  750mL    750
# 12260  19145  Gerard Bertrand La Viala Min  46.99  750mL    750
#
#        Classification  PurchasePrice  VendorNumber  \
# 0                   2          14.66          8320
# 1                   2           7.99          9165
# ...

# %% [markdown]
# The purchases price table Describes data about brands including its Price, Size, Volume and Purchase price.

# %%
vendor_invoice = pd.read_sql("select * from vendor_invoice",engine)
vendor_invoice
# Out:
#       VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0              105  ALTAMAR BRANDS LLC           2024-01-04      8124
# 1             4466  AMERICAN VINTAGE BEVERAGE    2024-01-07      8137
# 2              388  ATLANTIC IMPORTING COMPANY   2024-01-09      8169
# 3              480  BACARDI USA INC              2024-01-12      8106
# 4              516  BANFI PRODUCTS CORP          2024-01-07      8170
# ...            ...                          ...         ...       ...
# 5538          9622  WEIN BAUER INC               2025-01-06     13626
# 5539          9625  WESTERN SPIRITS BEVERAGE CO  2025-01-10     13661
# 5540          3664  WILLIAM GRANT & SONS INC     2025-01-02     13643
# 5541          9815  WINE GROUP INC               2025-01-03     13602
# 5542         90058  ZORVINO VINEYARDS            2025-01-05     13574
#
#           PODate     PayDate  Quantity    Dollars  Freight Approval
# ...

# %% [markdown]
# The vendor invoice table contains actual Invoice Data , Invoide date, Quantity, Total Sales and PO number.

# %%
sales = pd.read_sql("select * from sales",engine)
sales.head()
# Out:
#            InventoryId  Store  Brand                 Description        Size  \
# 0  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 1  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 2  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 3  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 4  1_HARDERSFIELD_1005      1   1005     Maker's Mark Combo Pack  375mL 2 Pk
#
#    SalesQuantity  SalesDollars  SalesPrice   SalesDate  Volume  \
# 0              1         16.49       16.49  2024-01-01   750.0
# 1              2         32.98       16.49  2024-01-02   750.0
# 2              1         16.49       16.49  2024-01-03   750.0
# 3              1         14.49       14.49  2024-01-08   750.0
# 4              2         69.98       34.99  2024-01-09   375.0
#
#    Classification  ExciseTax  VendorNo                   VendorName
# ...

# %% [markdown]
# The Sales Table Contains Whole Sales Transactions including brand purchased by vendor , total quantity sold, selling price and revenue earned.

# %%
begin_inventory = pd.read_sql("select * from begin_inventory",engine)
begin_inventory.head()
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
# 2  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
# 3  1_HARDERSFIELD_63      1  HARDERSFIELD     63   Herradura Reposado Tequila
# 4  1_HARDERSFIELD_72      1  HARDERSFIELD     72         No. 3 London Dry Gin
#
#     Size  onHand  Price   startDate
# 0  750mL       8  12.99  2024-01-01
# 1  750mL       7  10.99  2024-01-01
# 2  750mL       6  36.99  2024-01-01
# 3  750mL       3  38.99  2024-01-01
# 4  750mL       6  34.99  2024-01-01

# %% [markdown]
# Begin Inventory Table contains inventory data from start of the year.

# %%
end_inventory = pd.read_sql("select * from end_inventory",engine)
end_inventory.head()
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
# 2  1_HARDERSFIELD_63      1  HARDERSFIELD     63   Herradura Reposado Tequila
# 3  1_HARDERSFIELD_72      1  HARDERSFIELD     72         No. 3 London Dry Gin
# 4  1_HARDERSFIELD_75      1  HARDERSFIELD     75    Three Olives Tomato Vodka
#
#     Size  onHand  Price     endDate
# 0  750mL      11  12.99  2024-12-31
# 1  750mL       7  36.99  2024-12-31
# 2  750mL       7  38.99  2024-12-31
# 3  750mL       4  34.99  2024-12-31
# 4  750mL       7  14.99  2024-12-31

# %% [markdown]
# End Inventory table contains inventory data in the end of the year.

# %%
vendor_invoice.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'InvoiceDate', 'PONumber', 'PODate',
#        'PayDate', 'Quantity', 'Dollars', 'Freight', 'Approval'],
#       dtype='object')

# %% [markdown]
# Creating Summery Tables For Creating Aggregate Table

# %%
freight_summery = pd.read_sql("select vendorNumber, sum(freight) as total_freight_charges " \
"from vendor_invoice group by vendorNumber order by vendornumber",engine)

freight_summery
# Out:
#      vendorNumber  total_freight_charges
# 0               2                  27.08
# 1              54                   0.48
# 2              60                 367.52
# 3             105                  62.39
# 4             200                   6.19
# ..            ...                    ...
# 121         98450                 856.02
# 122         99166                 130.09
# 123        172662                 178.34
# 124        173357                 202.50
# 125        201359                   0.09
#
# [126 rows x 2 columns]

# %%
purchases.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'VendorNumber',
#        'VendorName', 'PONumber', 'PODate', 'ReceivingDate', 'InvoiceDate',
#        'PayDate', 'PurchasePrice', 'Quantity', 'Dollars', 'Classification'],
#       dtype='object')

# %%
purchase_prices.columns
# Out:
# Index(['Brand', 'Description', 'Price', 'Size', 'Volume', 'Classification',
#        'PurchasePrice', 'VendorNumber', 'VendorName'],
#       dtype='object')

# %%
pd.read_sql("""select p.vendornumber,p.vendorname,p.brand,p.purchaseprice,pp.volume,pp.price as actualPrice,
sum(p.quantity) as totalPurchaseQuantity , sum(p.dollars) as totalPurchaseDollars from purchases p join purchase_prices pp
on p.brand=pp.brand where p.purchaseprice > 0 group by p.vendornumber,p.vendorname,p.brand,p.purchaseprice,pp.volume,pp.price order by totalPurchaseDollars""",engine)
# Out:
#        vendornumber                   vendorname  brand  purchaseprice volume  \
# 0              7245  PROXIMO SPIRITS INC.          3065           0.71     50
# 1              3960  DIAGEO NORTH AMERICA INC      6127           1.47    200
# 2              3924  HEAVEN HILL DISTILLERIES      9123           0.74     50
# 3              8004  SAZERAC CO INC                5683           0.39     50
# 4              9815  WINE GROUP INC                8527           1.32    750
# ...             ...                          ...    ...            ...    ...
# 10687          3960  DIAGEO NORTH AMERICA INC      3545          21.89   1750
# 10688          3960  DIAGEO NORTH AMERICA INC      4261          16.17   1750
# 10689         17035  PERNOD RICARD USA             8068          18.24   1750
# 10690          4425        MARTIGNETTI COMPANIES   3405          23.19   1750
# 10691          1128  BROWN-FORMAN CORP             1233          26.27   1750
#
# ...

# %%
sales.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'SalesQuantity',
#        'SalesDollars', 'SalesPrice', 'SalesDate', 'Volume', 'Classification',
#        'ExciseTax', 'VendorNo', 'VendorName'],
#       dtype='object')

# %%
pd.read_sql("""select 
vendorno,
brand,
sum(salesdollars) as totalSalesDollars,
sum(salesprice) as totalSalesPrice,
sum(salesQuantity) as totalSalesQunatity,
sum(ExciseTax) as totalExciseTax
from sales
group by vendorNo,brand
order by totalSalesDollars
""",engine)
# Out:
#        vendorno  brand  totalSalesDollars  totalSalesPrice  \
# 0          8004   5287               0.98             0.98
# 1          9206   2773               0.99             0.99
# 2          3252   3933               1.98             0.99
# 3         10050   3623               1.98             1.98
# 4          3924   9123               1.98             0.99
# ...         ...    ...                ...              ...
# 11267      3960   3545         4223107.62        545778.28
# 11268      3960   4261         4475972.88        420050.01
# 11269     17035   8068         4538120.60        461140.15
# 11270      4425   3405         4819073.49        561512.37
# 11271      1128   1233         5101919.51        672819.31
#
#        totalSalesQunatity  totalExciseTax
# 0                       2            0.10
# 1                       1            0.05
# 2                       2            0.10
# 3                       2            0.10
# ...

# %% [markdown]
# Creating Single Table with all aggregate values for Performance Optimization.

# %%
vendor_sales_summery = pd.read_sql("""with FreightSummery AS(
select vendorNumber, sum(freight) as totalFreightCharges
from vendor_invoice group by vendorNumber),
                                   
PurchaseSummery AS (
select p.vendornumber,p.vendorname,p.brand,p.description,p.purchaseprice,pp.volume,pp.price as actualPrice,
sum(p.quantity) as totalPurchaseQuantity , sum(p.dollars) as totalPurchaseDollars from purchases p join purchase_prices pp
on p.brand=pp.brand where p.purchaseprice > 0 group by p.vendornumber,p.vendorname,p.brand,p.description,p.purchaseprice,pp.volume,pp.price                            
),
                                   
SalesSummery AS (
select 
vendorno,
brand,
sum(salesdollars) as totalSalesDollars,
sum(salesprice) as totalSalesPrice,
sum(salesQuantity) as totalSalesQunatity,
sum(ExciseTax) as totalExciseTax
from sales
group by vendorNo,brand
)
                                   
Select  
ps.vendornumber,ps.vendorname,ps.brand,ps.description,ps.purchaseprice,ps.actualPrice,ps.volume,ps.totalPurchaseQuantity,ps.totalPurchaseDollars,
ss.totalSalesQunatity,ss.totalSalesDollars,ss.totalSalesPrice,ss.totalExciseTax,fs.totalFreightCharges
from PurchaseSummery ps
left join SalesSummery ss
ON ps.vendornumber = ss.vendorno and ps.brand = ss.brand
left join FreightSummery fs
on ps.vendornumber = fs.vendornumber
order by ps.totalPurchaseDollars desc""",engine)

# %%
vendor_sales_summery
# Out:
#        vendornumber                   vendorname  brand  \
# 0              1128  BROWN-FORMAN CORP             1233
# 1              4425        MARTIGNETTI COMPANIES   3405
# 2             17035  PERNOD RICARD USA             8068
# 3              3960  DIAGEO NORTH AMERICA INC      4261
# 4              3960  DIAGEO NORTH AMERICA INC      3545
# ...             ...                          ...    ...
# 10687          9815  WINE GROUP INC                8527
# 10688          8004  SAZERAC CO INC                5683
# 10689          3924  HEAVEN HILL DISTILLERIES      9123
# 10690          3960  DIAGEO NORTH AMERICA INC      6127
# 10691          7245  PROXIMO SPIRITS INC.          3065
#
#                        description  purchaseprice  actualPrice volume  \
# 0          Jack Daniels No 7 Black          26.27        36.99   1750
# 1            Tito's Handmade Vodka          23.19        28.99   1750
# 2                 Absolut 80 Proof          18.24        24.99   1750
# ...

# %% [markdown]
# Data Cleaning

# %%
vendor_sales_summery.dtypes
# Out:
# vendornumber               int64
# vendorname                object
# brand                      int64
# description               object
# purchaseprice            float64
# actualPrice              float64
# volume                    object
# totalPurchaseQuantity      int64
# totalPurchaseDollars     float64
# totalSalesQunatity       float64
# totalSalesDollars        float64
# totalSalesPrice          float64
# totalExciseTax           float64
# totalFreightCharges      float64
# dtype: object

# %%
vendor_sales_summery.isna().sum()
# Out:
# vendornumber               0
# vendorname                 0
# brand                      0
# description                0
# purchaseprice              0
# actualPrice                0
# volume                     0
# totalPurchaseQuantity      0
# totalPurchaseDollars       0
# totalSalesQunatity       178
# totalSalesDollars        178
# totalSalesPrice          178
# totalExciseTax           178
# totalFreightCharges        0
# dtype: int64

# %% [markdown]
# Changing Data Type

# %%
vendor_sales_summery['volume'] = vendor_sales_summery['volume'].astype('float64')

# %%
vendor_sales_summery['vendorname'].unique()
# Out:
# array(['BROWN-FORMAN CORP          ', 'MARTIGNETTI COMPANIES',
#        'PERNOD RICARD USA          ', 'DIAGEO NORTH AMERICA INC   ',
#        'BACARDI USA INC            ', 'JIM BEAM BRANDS COMPANY    ',
#        'MAJESTIC FINE WINES        ', 'ULTRA BEVERAGE COMPANY LLP ',
#        'STOLI GROUP,(USA) LLC      ', 'PROXIMO SPIRITS INC.       ',
#        'MOET HENNESSY USA INC      ', 'CAMPARI AMERICA            ',
#        'SAZERAC CO INC             ', 'CONSTELLATION BRANDS INC   ',
#        'M S WALKER INC             ', 'SAZERAC NORTH AMERICA INC. ',
#        'PALM BAY INTERNATIONAL INC ', 'REMY COINTREAU USA INC     ',
#        'SIDNEY FRANK IMPORTING CO  ', 'E & J GALLO WINERY         ',
#        'WILLIAM GRANT & SONS INC   ', 'HEAVEN HILL DISTILLERIES   ',
#        'DISARONNO INTERNATIONAL LLC', 'EDRINGTON AMERICAS         ',
#        'CASTLE BRANDS CORP.        ', 'SOUTHERN WINE & SPIRITS NE ',
#        'STE MICHELLE WINE ESTATES  ', 'TRINCHERO FAMILY ESTATES   ',
# ...

# %% [markdown]
# Removing Extra Spaces

# %%
vendor_sales_summery['vendorname'] = vendor_sales_summery['vendorname'].str.strip()

# %% [markdown]
# Filling Null Values

# %%
vendor_sales_summery.fillna(0,inplace=True)

# %%
vendor_sales_summery.isnull().sum()
# Out:
# vendornumber             0
# vendorname               0
# brand                    0
# description              0
# purchaseprice            0
# actualPrice              0
# volume                   0
# totalPurchaseQuantity    0
# totalPurchaseDollars     0
# totalSalesQunatity       0
# totalSalesDollars        0
# totalSalesPrice          0
# totalExciseTax           0
# totalFreightCharges      0
# dtype: int64

# %% [markdown]
# Creating New Columns For Data Analysis

# %%
vendor_sales_summery['grossProfit'] = vendor_sales_summery['totalSalesDollars'] - vendor_sales_summery['totalPurchaseDollars']

# %%
vendor_sales_summery['profitMargin'] = (vendor_sales_summery['grossProfit']/vendor_sales_summery['totalSalesDollars'])*100

# %%
vendor_sales_summery['stockTurnover'] = vendor_sales_summery['totalSalesQunatity']/vendor_sales_summery['totalPurchaseQuantity']

# %%
vendor_sales_summery['salesToPurchaseRatio'] = vendor_sales_summery['totalSalesDollars']/vendor_sales_summery['totalPurchaseDollars']

# %%
vendor_sales_summery.head()
# Out:
#    vendornumber                vendorname  brand              description  \
# 0          1128         BROWN-FORMAN CORP   1233  Jack Daniels No 7 Black
# 1          4425     MARTIGNETTI COMPANIES   3405    Tito's Handmade Vodka
# 2         17035         PERNOD RICARD USA   8068         Absolut 80 Proof
# 3          3960  DIAGEO NORTH AMERICA INC   4261   Capt Morgan Spiced Rum
# 4          3960  DIAGEO NORTH AMERICA INC   3545          Ketel One Vodka
#
#    purchaseprice  actualPrice  volume  totalPurchaseQuantity  \
# 0          26.27        36.99  1750.0                 145080
# 1          23.19        28.99  1750.0                 164038
# 2          18.24        24.99  1750.0                 187407
# 3          16.17        22.99  1750.0                 201682
# 4          21.89        29.99  1750.0                 138109
#
#    totalPurchaseDollars  totalSalesQunatity  totalSalesDollars  \
# 0            3811251.60            142049.0         5101919.51
# ...

# %%
vendor_sales_summery.dtypes
# Out:
# vendornumber               int64
# vendorname                object
# brand                      int64
# description               object
# purchaseprice            float64
# actualPrice              float64
# volume                   float64
# totalPurchaseQuantity      int64
# totalPurchaseDollars     float64
# totalSalesQunatity         int64
# totalSalesDollars        float64
# totalSalesPrice          float64
# totalExciseTax           float64
# totalFreightCharges      float64
# grossProfit              float64
# profitMargin             float64
# stockTurnover            float64
# salesToPurchaseRatio     float64
# dtype: object

# %%
vendor_sales_summery['totalSalesQunatity'] = vendor_sales_summery['totalSalesQunatity'].astype('int')

# %%
vendor_sales_summery.isnull().sum()
# Out:
# vendornumber             0
# vendorname               0
# brand                    0
# description              0
# purchaseprice            0
# actualPrice              0
# volume                   0
# totalPurchaseQuantity    0
# totalPurchaseDollars     0
# totalSalesQunatity       0
# totalSalesDollars        0
# totalSalesPrice          0
# totalExciseTax           0
# totalFreightCharges      0
# grossProfit              0
# profitMargin             0
# stockTurnover            0
# salesToPurchaseRatio     0
# dtype: int64

# %%
import numpy as np

# %%
vendor_sales_summery.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
vendor_sales_summery = vendor_sales_summery.fillna(0)

# %%
vendor_sales_summery.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10692 entries, 0 to 10691
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   vendornumber           10692 non-null  int64
#  1   vendorname             10692 non-null  object
#  2   brand                  10692 non-null  int64
#  3   description            10692 non-null  object
#  4   purchaseprice          10692 non-null  float64
#  5   actualPrice            10692 non-null  float64
#  6   volume                 10692 non-null  float64
#  7   totalPurchaseQuantity  10692 non-null  int64
#  8   totalPurchaseDollars   10692 non-null  float64
#  9   totalSalesQunatity     10692 non-null  int64
#  10  totalSalesDollars      10692 non-null  float64
#  11  totalSalesPrice        10692 non-null  float64
#  12  totalExciseTax         10692 non-null  float64
#  13  totalFreightCharges    10692 non-null  float64
# ...

# %% [markdown]
# Creating table in SQL server database.

# %%
vendor_sales_summery.to_sql(
    "vendor_sales_summary",
    con=engine,
    if_exists='replace',
    index=False
)
# Out:
# 20

# %%
pd.read_sql("select * from vendor_sales_summary",engine)
# Out:
#        vendornumber                vendorname  brand  \
# 0              1128         BROWN-FORMAN CORP   1233
# 1              4425     MARTIGNETTI COMPANIES   3405
# 2             17035         PERNOD RICARD USA   8068
# 3              3960  DIAGEO NORTH AMERICA INC   4261
# 4              3960  DIAGEO NORTH AMERICA INC   3545
# ...             ...                       ...    ...
# 10687          9815            WINE GROUP INC   8527
# 10688          8004            SAZERAC CO INC   5683
# 10689          3924  HEAVEN HILL DISTILLERIES   9123
# 10690          3960  DIAGEO NORTH AMERICA INC   6127
# 10691          7245      PROXIMO SPIRITS INC.   3065
#
#                        description  purchaseprice  actualPrice  volume  \
# 0          Jack Daniels No 7 Black          26.27        36.99  1750.0
# 1            Tito's Handmade Vodka          23.19        28.99  1750.0
# 2                 Absolut 80 Proof          18.24        24.99  1750.0
# ...

# %% [markdown]
# Summery :-
#
# -> Now the new table is created with the all aggregated columns.
#
# -> We can perform data visualization on this.
#
# -> Also this can be used for insights and Dashboard.
